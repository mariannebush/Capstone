# %% [markdown]
# Loading the pandas library and importing Google Drive

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# Mounting the Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Reading in two .xls files

# %%
'/content/drive/My Drive/file.xls'
happy1 = pd.read_excel('/content/drive/My Drive/DataForFigure2.1WHR2024.xls')
happy2 = pd.read_excel('/content/drive/My Drive/DataForTable2.1WHR2024.xls')

# %% [markdown]
# Print the column names for the first .xls file

# %%
print(happy1.columns)
# Out:
# Index(['Country name', 'Ladder score', 'upperwhisker', 'lowerwhisker',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %% [markdown]
# Print the column names for the second .xls file

# %%
print(happy2.columns)
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %% [markdown]
# Rename the columns in Happy1 so that they match Happy2

# %%
happy1.rename(columns={'Ladder score': 'Life Ladder',
                        'Explained by: Log GDP per capita': 'Log GDP per capita',
                        'Explained by: Social support': 'Social support',
                        'Explained by: Healthy life expectancy': 'Healthy life expectancy at birth',
                        'Explained by: Freedom to make life choices': 'Freedom to make life choices',
                        'Explained by: Generosity': 'Generosity',
                        'Explained by: Perceptions of corruption': 'Perceptions of corruption'}, inplace=True)

# %% [markdown]
# Print the column names to ensure the changes have been made

# %%
print(happy1.columns)
# Out:
# Index(['Country name', 'Life Ladder', 'upperwhisker', 'lowerwhisker',
#        'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')

# %% [markdown]
# Add a "Year" column to Happy1 and fill it in with 2024

# %%
happy1['year'] = 2024
happy1.head()
# Out:
#   Country name  Life Ladder  upperwhisker  lowerwhisker  Log GDP per capita  \
# 0      Finland       7.7407      7.814808      7.666591            1.844054
# 1      Denmark       7.5827      7.665297      7.500103            1.907798
# 2      Iceland       7.5251      7.617527      7.432673            1.880718
# 3       Sweden       7.3441      7.421563      7.266637            1.878146
# 4       Israel       7.3411      7.405165      7.277036            1.802934
#
#    Social support  Healthy life expectancy at birth  \
# 0        1.572367                          0.694793
# 1        1.520361                          0.698944
# 2        1.616525                          0.718345
# 3        1.500826                          0.723871
# 4        1.512793                          0.739816
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.859294    0.141674                   0.546158
# 1                      0.822740    0.203579                   0.548413
# 2                      0.818509    0.258344                   0.182473
# 3                      0.838269    0.221455                   0.523795
# 4                      0.641463    0.153205                   0.192823
#
#    Dystopia + residual  year
# 0             2.082367  2024
# 1             1.880887  2024
# 2             2.050233  2024
# 3             1.657707  2024
# 4             2.298026  2024

# %% [markdown]
# Create the combined dataframe by combining Happy1 and Happy2

# %%
combined_df = pd.concat([happy1, happy2], ignore_index=True)
print(combined_df)
# Out:
#      Country name  Life Ladder  upperwhisker  lowerwhisker  \
# 0         Finland     7.740700      7.814808      7.666591
# 1         Denmark     7.582700      7.665297      7.500103
# 2         Iceland     7.525100      7.617527      7.432673
# 3          Sweden     7.344100      7.421563      7.266637
# 4          Israel     7.341100      7.405165      7.277036
# ...           ...          ...           ...           ...
# 2501     Zimbabwe     2.693523           NaN           NaN
# 2502     Zimbabwe     3.159802           NaN           NaN
# 2503     Zimbabwe     3.154578           NaN           NaN
# 2504     Zimbabwe     3.296220           NaN           NaN
# 2505     Zimbabwe     3.572386           NaN           NaN
#
#       Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0               1.844054        1.572367                          0.694793
# 1               1.907798        1.520361                          0.698944
# 2               1.880718        1.616525                          0.718345
# 3               1.878146        1.500826                          0.723871
# 4               1.802934        1.512793                          0.739816
# ...                  ...             ...                               ...
# 2501            7.697755        0.759162                         53.099998
# 2502            7.596050        0.717243                         53.575001
# 2503            7.656878        0.685151                         54.049999
# 2504            7.670073        0.666172                         54.525002
# 2505            7.678590        0.693817                         55.000000
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.859294    0.141674                   0.546158
# 1                         0.822740    0.203579                   0.548413
# 2                         0.818509    0.258344                   0.182473
# 3                         0.838269    0.221455                   0.523795
# 4                         0.641463    0.153205                   0.192823
# ...                            ...         ...                        ...
# 2501                      0.631908   -0.050874                   0.830652
# 2502                      0.643303    0.002848                   0.788523
# 2503                      0.667636   -0.079007                   0.756945
# 2504                      0.651987   -0.072935                   0.752632
# 2505                      0.734613   -0.068837                   0.757494
#
#       Dystopia + residual  year  Positive affect  Negative affect
# 0                2.082367  2024              NaN              NaN
# 1                1.880887  2024              NaN              NaN
# 2                2.050233  2024              NaN              NaN
# 3                1.657707  2024              NaN              NaN
# 4                2.298026  2024              NaN              NaN
# ...                   ...   ...              ...              ...
# 2501                  NaN  2019         0.658434         0.235354
# 2502                  NaN  2020         0.660658         0.345736
# 2503                  NaN  2021         0.609917         0.241682
# 2504                  NaN  2022         0.640609         0.191350
# 2505                  NaN  2023         0.609752         0.178953
#
# [2506 rows x 14 columns]

# %% [markdown]
# Drop upperwhisker and lowerwhisker variables from the combined dataframe

# %%
combined_df.drop(['upperwhisker', 'lowerwhisker'], axis='columns', inplace=True)

# %% [markdown]
# Print the combined dataframe

# %%
print(combined_df)
# Out:
#      Country name  Life Ladder  Log GDP per capita  Social support  \
# 0         Finland     7.740700            1.844054        1.572367
# 1         Denmark     7.582700            1.907798        1.520361
# 2         Iceland     7.525100            1.880718        1.616525
# 3          Sweden     7.344100            1.878146        1.500826
# 4          Israel     7.341100            1.802934        1.512793
# ...           ...          ...                 ...             ...
# 2501     Zimbabwe     2.693523            7.697755        0.759162
# 2502     Zimbabwe     3.159802            7.596050        0.717243
# 2503     Zimbabwe     3.154578            7.656878        0.685151
# 2504     Zimbabwe     3.296220            7.670073        0.666172
# 2505     Zimbabwe     3.572386            7.678590        0.693817
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                             0.694793                      0.859294
# 1                             0.698944                      0.822740
# 2                             0.718345                      0.818509
# 3                             0.723871                      0.838269
# 4                             0.739816                      0.641463
# ...                                ...                           ...
# 2501                         53.099998                      0.631908
# 2502                         53.575001                      0.643303
# 2503                         54.049999                      0.667636
# 2504                         54.525002                      0.651987
# 2505                         55.000000                      0.734613
#
#       Generosity  Perceptions of corruption  Dystopia + residual  year  \
# 0       0.141674                   0.546158             2.082367  2024
# 1       0.203579                   0.548413             1.880887  2024
# 2       0.258344                   0.182473             2.050233  2024
# 3       0.221455                   0.523795             1.657707  2024
# 4       0.153205                   0.192823             2.298026  2024
# ...          ...                        ...                  ...   ...
# 2501   -0.050874                   0.830652                  NaN  2019
# 2502    0.002848                   0.788523                  NaN  2020
# 2503   -0.079007                   0.756945                  NaN  2021
# 2504   -0.072935                   0.752632                  NaN  2022
# 2505   -0.068837                   0.757494                  NaN  2023
#
#       Positive affect  Negative affect
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ...               ...              ...
# 2501         0.658434         0.235354
# 2502         0.660658         0.345736
# 2503         0.609917         0.241682
# 2504         0.640609         0.191350
# 2505         0.609752         0.178953
#
# [2506 rows x 12 columns]

# %% [markdown]
# Print the number of missing values

# %%
missing_values=combined_df.isnull().sum()
print(missing_values)
# Out:
# Country name                           0
# Life Ladder                            0
# Log GDP per capita                    31
# Social support                        16
# Healthy life expectancy at birth      66
# Freedom to make life choices          39
# Generosity                            84
# Perceptions of corruption            128
# Dystopia + residual                 2366
# year                                   0
# Positive affect                      167
# Negative affect                      159
# dtype: int64

# %% [markdown]
# Drop Dystopia + residual, Positive affect, & Negative affect variables from the combined dataframe

# %%
combined_df.drop(['Dystopia + residual', 'Positive affect', 'Negative affect'], axis='columns', inplace=True)

# %% [markdown]
# Print the number of missing values

# %%
missing_values=combined_df.isnull().sum()
print(missing_values)
# Out:
# Country name                          0
# Life Ladder                           0
# Log GDP per capita                   31
# Social support                       16
# Healthy life expectancy at birth     66
# Freedom to make life choices         39
# Generosity                           84
# Perceptions of corruption           128
# year                                  0
# dtype: int64

# %% [markdown]
# Replace missing (null) values with N/A

# %%
combined_df.fillna('N/A', inplace=True)

# %% [markdown]
# Print the number of missing values

# %%
missing_values=combined_df.isnull().sum()
print(missing_values)
# Out:
# Country name                        0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# year                                0
# dtype: int64

# %% [markdown]
# Print the combined dataframe into a .csv file

# %%
combined_df.to_csv('/content/drive/My Drive/combined_df.csv', index=False)
